# %%
# %matplotlib inline

import matplotlib.font_manager as fm
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
# Out:
# /Users/Spepe/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:1004: UserWarning: Illegal line #11
# 	"font.family  monospace
# "
# 	in file "/Users/Spepe/anaconda/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/spe.mplstyle"
#   warnings.warn('Illegal %s' % error_details)

# %% [markdown]
# http://matplotlib.org/faq/troubleshooting_faq.html
#
# http://geeksta.net/geeklog/custom-matplotlib-styles/

# %%
print(mpl.get_configdir())
# Out:
# /Users/Spepe/.matplotlib

# %%
print(mpl.get_cachedir())
# Out:
# /Users/Spepe/.matplotlib

# %%
print(mpl.matplotlib_fname())
# Out:
# /Users/Spepe/anaconda/lib/python2.7/site-packages/matplotlib/mpl-data/matplotlibrc

# %% [markdown]
# After putting customized stylesheets in subdir, the first step is ALWAYS ALWAYS ALWAYS restarting the ipython notebook, or you will spend an clueless hour of troubleshooting like me ahhhhhhh.

# %%
plt.style.available
# Out:
# [u'grayscale',
#  u'bmh',
#  u'dark_background',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'spe']

# %% [markdown]
# http://pandas.pydata.org/pandas-docs/stable/visualization.html

# %% [markdown]
# ## Line Chart

# %%
# Get current size
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 5.0]
print "Current size:", fig_size

# Set new figure width to 8 and height to 5
fig_size[0] = 8
fig_size[1] = 5
plt.rcParams["figure.figsize"] = fig_size
# Out:
# Current size: [6.0, 4.0]

# %%
plt.style.use('ggplot')

ts = pd.Series(np.random.randn(100), index=pd.date_range('1/1/2000', periods=100))
ts = ts.cumsum()
ts.plot()

# %%
plt.style.use('fivethirtyeight')

ts = pd.Series(np.random.randn(100), index=pd.date_range('1/1/2000', periods=100))
ts = ts.cumsum()
ts.plot()

# %%
plt.style.use('spe')

#adding only x-axis and y-axis
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.spines['bottom'].set_color('#a1a1a1')
ax.spines['left'].set_color('#a1a1a1')
#### 

ts = pd.Series(np.random.randn(100), index=pd.date_range('1/1/2000', periods=100))
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(100, 4), index=ts.index, columns=list('ABCD'))

df = df.cumsum()

plt.figure(); df.plot();

# %% [markdown]
# still don't know how to add new fonts not in matpltlib default
# I WANT LATO!!!!
